# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
train = pd.read_csv('data/click.csv')

# %%
train_x = train['x']
train_y = train['y']

# %%
plt.scatter(train_x, train_y)
plt.show()

# %% [markdown]
# $$
# f_{\theta}(x) = \theta_0 + \theta_1 x \\
# E(\theta) = \dfrac{1}{2} \sum^n_{i=1} \left(y^{(i)} - f_{\theta}(x^{(i)}) \right)^2
# $$

# %% [markdown]
# $$ z^{(i)} = \dfrac{x^{(i)} - \mu}{\sigma} $$
# 표준화 또는 정규화 전처리를 통해 매개변수 수렴속도를 단축 시킬수 있다

# %%
mu = train_x.mean()
sigima = train_x.std()
def standardize(x):

    return (x-mu) / sigima

# %%
train_z = standardize(train_x)

# %%
plt.scatter(train_z, train_y)
plt.show()

# %%
theta0 = np.random.rand()
theta1 = np.random.rand()

# %%
def f(x):
    return theta0 + theta1 * x

def E(x, y):
    return 0.5 * np.sum((y - f(x))**2)

# %%
# learning rate
ETA = 0.001

diff = 1

count = 0

error = E(train_z, train_y)
theta0, theta1, error
# Out:
# (0.09858670313890072, 0.13189637206639382, 1937537.2463849583)

# %%
res = []
while diff > 0.01:
    tmp0 = theta0 - ETA * np.sum( f(train_z) - train_y )
    tmp1 = theta1 - ETA * np.sum( (f(train_z) - train_y) * train_z )
    
    theta0 = tmp0
    theta1 = tmp1
    
    current_error = E(train_z, train_y)
    diff = error - current_error
    error = current_error
    
    count += 1
    #log = '%d : t0:%f, t1:%f, diff:%f, error:%f'%(count, theta0, theta1, diff, error)
    #print(log)
    res.append([theta0, theta1, diff, error])

res = pd.DataFrame(res, columns=['theta0','theta1','diff','error'])

# %%
res
# Out:
#          theta0     theta1          diff         error
# 0      8.679615   1.951627  76177.666691  1.861360e+06
# 1     17.089023   3.736783  73167.463093  1.788192e+06
# 2     25.330242   5.488021  70276.221464  1.717916e+06
# 3     33.406637   7.205985  67499.240022  1.650417e+06
# 4     41.321505   8.891308  64832.002832  1.585585e+06
# 5     49.078075  10.544610  62270.172460  1.523314e+06
# 6     56.679513  12.166499  59809.582920  1.463505e+06
# 7     64.128923  13.757572  57446.232889  1.406059e+06
# 8     71.429344  15.318415  55176.279204  1.350882e+06
# 9     78.583757  16.849601  52996.030609  1.297886e+06
# 10    85.595082  18.351696  50901.941749  1.246984e+06
# 11    92.466181  19.825250  48890.607401  1.198094e+06
# 12    99.199857  21.270807  46958.756939  1.151135e+06
# 13   105.798860  22.688898  45103.249009  1.106032e+06
# 14   112.265883  24.080046  43321.066422  1.062711e+06
# 15   118.603565  25.444762  41609.311245  1.021101e+06
# 16   124.814494  26.783548  39965.200086  9.811362e+05
# 17   130.901204  28.096897  38386.059568  9.427502e+05
# 18   136.866180  29.385293  36869.321977  9.058808e+05
# 19   142.711856  30.649209  35412.521090  8.704683e+05
# 20   148.440619  31.889110  34013.288161  8.364550e+05
# 21   154.054807  33.105454  32669.348065  8.037857e+05
# 22   159.556711  34.298687  31378.515602  7.724072e+05
# 23   164.948576  35.469249  30138.691941  7.422685e+05
# 24   170.232605  36.617570  28947.861205  7.133206e+05
# 25   175.410953  37.744072  27804.087190  6.855165e+05
# 26   180.485734  38.849172  26705.510223  6.588110e+05
# 27   185.459019  39.933274  25650.344127  6.331607e+05
# 28   190.332839  40.996778  24636.873325  6.085238e+05
# 29   195.109182  42.040076  23663.450043  5.848603e+05
# ..          ...        ...           ...           ...
# 365  428.886213  95.821664      0.031409  9.544240e+03
# 366  428.891489  95.823289      0.030171  9.544210e+03
# 367  428.896659  95.824883      0.028981  9.544181e+03
# 368  428.901726  95.826447      0.027838  9.544153e+03
# 369  428.906691  95.827981      0.026741  9.544126e+03
# 370  428.911558  95.829486      0.025686  9.544100e+03
# 371  428.916326  95.830963      0.024674  9.544076e+03
# 372  428.921000  95.832411      0.023701  9.544052e+03
# 373  428.925580  95.833832      0.022766  9.544029e+03
# 374  428.930068  95.835226      0.021869  9.544007e+03
# 375  428.934467  95.836593      0.021006  9.543986e+03
# 376  428.938778  95.837934      0.020178  9.543966e+03
# 377  428.943002  95.839250      0.019383  9.543947e+03
# 378  428.947142  95.840541      0.018618  9.543928e+03
# 379  428.951199  95.841808      0.017884  9.543910e+03
# 380  428.955175  95.843050      0.017179  9.543893e+03
# 381  428.959072  95.844269      0.016502  9.543877e+03
# 382  428.962890  95.845464      0.015851  9.543861e+03
# 383  428.966632  95.846637      0.015226  9.543846e+03
# 384  428.970300  95.847787      0.014626  9.543831e+03
# 385  428.973894  95.848916      0.014050  9.543817e+03
# 386  428.977416  95.850023      0.013496  9.543803e+03
# 387  428.980868  95.851110      0.012964  9.543790e+03
# 388  428.984250  95.852175      0.012453  9.543778e+03
# 389  428.987565  95.853221      0.011962  9.543766e+03
# 390  428.990814  95.854246      0.011490  9.543755e+03
# 391  428.993998  95.855252      0.011037  9.543743e+03
# 392  428.997118  95.856239      0.010602  9.543733e+03
# 393  429.000175  95.857207      0.010184  9.543723e+03
# 394  429.003172  95.858157      0.009783  9.543713e+03
#
# [395 rows x 4 columns]

# %%
plt.subplot(121)
plt.plot(res['diff'])
plt.subplot(122)
plt.plot(res['error'])

# %%
xx = np.linspace(-3, 3, 100)
plt.scatter(train_z, train_y)
plt.plot(xx, f(xx))
plt.show()

# %%
f(standardize(100))
# Out:
# 370.9796299252364

# %% [markdown]
# # 다항회귀

# %%
def f(x):
    return np.dot(x, theta)

# %%
def to_matrix(x):
    return np.vstack([np.ones(x.shape[0]), x, x**2]).T

# %%
X = to_matrix(train_z)

# %%
theta = np.random.rand(3)

# %%
diff = 1

error = E(X, train_y)
error
# Out:
# 1925002.7855898854

# %%
res = []
while diff > 0.01:
    theta = theta - ETA * np.dot(f(X) - train_y, X)
    
    current_error = E(X, train_y)
    diff = error - current_error
    error = current_error

    res.append([theta, diff, error])

# %%
pd.DataFrame(res)
# Out:
#                                                      0              1  \
# 0    [9.287271224387048, 2.7501486555108614, 9.1684...  145283.746100
# 1    [17.510324433933857, 4.531908998400979, 17.180...  131790.621722
# 2    [25.41667999573354, 6.290107526488127, 24.7243...  119615.972354
# 3    [33.021582929574976, 8.024589500458708, 31.823...  108629.368105
# 4    [40.339509213872475, 9.735234498313657, 38.500...   98713.325562
# 5    [47.384204924005374, 11.421954157263183, 44.77...   89762.021358
# 803  [405.7044733247928, 97.57651118683579, 24.5309...       0.011161
# 804  [405.70729497691076, 97.57630307873522, 24.529...       0.010977
# 805  [405.71009319993647, 97.57609669352644, 24.527...       0.010795
# 806  [405.71286818841315, 97.57589201700029, 24.525...       0.010617
# 807  [405.71562013526864, 97.57568903506377, 24.524...       0.010441
# 808  [405.71834923182865, 97.57548773373914, 24.522...       0.010268
# 809  [405.7210556678301, 97.5752880991629, 24.52078...       0.010099
# 810  [405.7237396314345, 97.57509011758496, 24.5191...       0.009932
#
#                 2
# 0    1.779719e+06
# 1    1.647928e+06
# 2    1.528312e+06
# 3    1.419683e+06
# 4    1.320970e+06
# 5    1.231208e+06
# 6    1.149528e+06
# 7    1.075146e+06
# 8    1.007356e+06
# 9    9.455221e+05
# 10   8.890698e+05
# 11   8.374821e+05
# 12   7.902928e+05
# 13   7.470813e+05
# 14   7.074686e+05
# 15   6.711129e+05
# 16   6.377060e+05
# 17   6.069697e+05
# 18   5.786532e+05
# 19   5.525304e+05
# 20   5.283970e+05
# 21   5.060688e+05
# 22   4.853797e+05
# 23   4.661794e+05
# 24   4.483325e+05
# 25   4.317167e+05
# 26   4.162215e+05
# 27   4.017470e+05
# 28   3.882031e+05
# 29   3.755082e+05
# ..            ...
# 781  3.278820e+03
# 782  3.278804e+03
# 783  3.278789e+03
# 784  3.278773e+03
# 785  3.278758e+03
# 786  3.278744e+03
# 787  3.278729e+03
# 788  3.278715e+03
# 789  3.278701e+03
# 790  3.278687e+03
# 791  3.278673e+03
# 792  3.278660e+03
# 793  3.278646e+03
# 794  3.278634e+03
# 795  3.278621e+03
# 796  3.278608e+03
# 797  3.278596e+03
# 798  3.278584e+03
# 799  3.278572e+03
# 800  3.278560e+03
# 801  3.278549e+03
# 802  3.278537e+03
# 803  3.278526e+03
# 804  3.278515e+03
# 805  3.278504e+03
# 806  3.278494e+03
# 807  3.278483e+03
# 808  3.278473e+03
# 809  3.278463e+03
# 810  3.278453e+03
#
# [811 rows x 3 columns]

# %%
xx = np.linspace(-3, 3, 100)
plt.scatter(train_z, train_y)
plt.plot(xx, f(to_matrix(xx)))

# %%
def MSE(x, y):
    return (1 / x.shape[0]) * np.sum((y - f(x))**2)

# %%
theta = np.random.rand(3)

erros = []

diff = 1

erros.append(MSE(X, train_y))

# %%
res = []
while diff > 0.01:
    theta = theta - ETA * np.dot(f(X) - train_y, X)
    erros.append(MSE(X, train_y))
    diff = erros[-2] - erros[-1]    
    res.append([theta, diff])

# %%
plt.plot(np.arange(len(erros)), erros)
plt.show()

# %%
xx = np.linspace(-3, 3, 100)
plt.scatter(train_z, train_y)
plt.plot(xx, f(to_matrix(xx)))
plt.show()

# %%
theta = np.random.rand(3)

erros = []

diff = 1

erros.append(MSE(X, train_y))

# %%
ts = []
while diff > 0.01:
    p = np.random.permutation(X.shape[0])
    for x, y in zip(X[p,:], train_y[p]):
        # 섞인 데이터로 
        
        theta = theta - ETA * (f(x) - y) * x
        ts.append(theta)
    
    erros.append(MSE(X, train_y))
    diff = erros[-2] - erros[-1]

# %%
len(erros)
# Out:
# 675

# %%
ts = np.vstack(ts)
